# %%
import pandas as pd
df=pd.read_csv("house price.csv")
df
# Out:
#                      date         price  bedrooms  bathrooms  sqft_living  \
# 0     2014-05-02 00:00:00  3.130000e+05       3.0       1.50         1340
# 1     2014-05-02 00:00:00  2.384000e+06       5.0       2.50         3650
# 2     2014-05-02 00:00:00  3.420000e+05       3.0       2.00         1930
# 3     2014-05-02 00:00:00  4.200000e+05       3.0       2.25         2000
# 4     2014-05-02 00:00:00  5.500000e+05       4.0       2.50         1940
# ...                   ...           ...       ...        ...          ...
# 4595  2014-07-09 00:00:00  3.081667e+05       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  5.343333e+05       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  4.169042e+05       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  2.034000e+05       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  2.206000e+05       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
df.isnull().sum()
# Out:
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# street           0
# city             0
# statezip         0
# country          0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4600 entries, 0 to 4599
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           4600 non-null   object
#  1   price          4600 non-null   float64
#  2   bedrooms       4600 non-null   float64
#  3   bathrooms      4600 non-null   float64
#  4   sqft_living    4600 non-null   int64
#  5   sqft_lot       4600 non-null   int64
#  6   floors         4600 non-null   float64
#  7   waterfront     4600 non-null   int64
#  8   view           4600 non-null   int64
#  9   condition      4600 non-null   int64
#  10  sqft_above     4600 non-null   int64
#  11  sqft_basement  4600 non-null   int64
#  12  yr_built       4600 non-null   int64
#  13  yr_renovated   4600 non-null   int64
#  14  street         4600 non-null   object
#  15  city           4600 non-null   object
#  16  statezip       4600 non-null   object
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.kdeplot(data=df["bedrooms"],color="Green",fill=True)
plt.title("Distribution")
plt.show()

# %%
sns.kdeplot(data=df["bathrooms"],color="Green",fill=True)
plt.title("Distribution")
plt.show()

# %% [markdown]
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# street           0
# city             0
# statezip         0
# country

# %%
sns.kdeplot(data=df["sqft_living"],color="Green",fill=True)
plt.title("Distribution")
plt.show()

# %%
sns.kdeplot(data=df["sqft_lot"],color="Green",fill=True)
plt.title("Distribution")
plt.show()

# %%
sns.kdeplot(data=df["floors"],color="Green",fill=True)
plt.title("Distribution")
plt.show()

# %%
sns.kdeplot(data=df["waterfront"],color="Green",fill=True)
plt.title("Distribution")
plt.show()

# %%
sns.kdeplot(data=df["view"],color="Green",fill=True)
plt.title("Distribution")
plt.show()

# %%
sns.kdeplot(data=df["condition"],color="Green",fill=True)
plt.title("Distribution")
plt.show()

# %%
sns.kdeplot(data=df["condition"],color="Green",fill=True)
plt.title("Distribution")
plt.show()

# %%
sns.kdeplot(data=df["sqft_above"],color="Green",fill=True)
plt.title("Distribution")
plt.show()

# %%
sns.kdeplot(data=df["sqft_basement"],color="Green",fill=True)
plt.title("Distribution")
plt.show()

# %%
sns.kdeplot(data=df["yr_built"],color="Green",fill=True)
plt.title("Distribution")
plt.show()

# %%
sns.kdeplot(data=df["yr_renovated"],color="Green",fill=True)
plt.title("Distribution")
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df["date"]=le.fit_transform(df["date"])
df["street"]=le.fit_transform(df["street"])
df["city"]=le.fit_transform(df["city"])
df["statezip"]=le.fit_transform(df["statezip"])
df["country"]=le.fit_transform(df["country"])
df
# Out:
#       date         price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0        0  3.130000e+05       3.0       1.50         1340      7912     1.5
# 1        0  2.384000e+06       5.0       2.50         3650      9050     2.0
# 2        0  3.420000e+05       3.0       2.00         1930     11947     1.0
# 3        0  4.200000e+05       3.0       2.25         2000      8030     1.0
# 4        0  5.500000e+05       4.0       2.50         1940     10500     1.0
# ...    ...           ...       ...        ...          ...       ...     ...
# 4595    68  3.081667e+05       3.0       1.75         1510      6360     1.0
# 4596    68  5.343333e+05       3.0       2.50         1460      7573     2.0
# 4597    68  4.169042e+05       3.0       2.50         3010      7014     2.0
# 4598    69  2.034000e+05       4.0       2.00         2090      6630     1.0
# 4599    69  2.206000e+05       3.0       2.50         1490      8102     2.0
#
# ...

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
df.drop(columns=["floors"],inplace=True)
df
# Out:
#       date         price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0        0  3.130000e+05       3.0       1.50         1340      7912
# 1        0  2.384000e+06       5.0       2.50         3650      9050
# 2        0  3.420000e+05       3.0       2.00         1930     11947
# 3        0  4.200000e+05       3.0       2.25         2000      8030
# 4        0  5.500000e+05       4.0       2.50         1940     10500
# ...    ...           ...       ...        ...          ...       ...
# 4595    68  3.081667e+05       3.0       1.75         1510      6360
# 4596    68  5.343333e+05       3.0       2.50         1460      7573
# 4597    68  4.169042e+05       3.0       2.50         3010      7014
# 4598    69  2.034000e+05       4.0       2.00         2090      6630
# 4599    69  2.206000e+05       3.0       2.50         1490      8102
#
#       waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# ...

# %%
df.drop(columns=["yr_built"],inplace=True)
df
# Out:
#       date         price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0        0  3.130000e+05       3.0       1.50         1340      7912
# 1        0  2.384000e+06       5.0       2.50         3650      9050
# 2        0  3.420000e+05       3.0       2.00         1930     11947
# 3        0  4.200000e+05       3.0       2.25         2000      8030
# 4        0  5.500000e+05       4.0       2.50         1940     10500
# ...    ...           ...       ...        ...          ...       ...
# 4595    68  3.081667e+05       3.0       1.75         1510      6360
# 4596    68  5.343333e+05       3.0       2.50         1460      7573
# 4597    68  4.169042e+05       3.0       2.50         3010      7014
# 4598    69  2.034000e+05       4.0       2.00         2090      6630
# 4599    69  2.206000e+05       3.0       2.50         1490      8102
#
#       waterfront  view  condition  sqft_above  sqft_basement  yr_renovated  \
# ...

# %%
df
# Out:
#       date         price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0        0  3.130000e+05       3.0       1.50         1340      7912
# 1        0  2.384000e+06       5.0       2.50         3650      9050
# 2        0  3.420000e+05       3.0       2.00         1930     11947
# 3        0  4.200000e+05       3.0       2.25         2000      8030
# 4        0  5.500000e+05       4.0       2.50         1940     10500
# ...    ...           ...       ...        ...          ...       ...
# 4595    68  3.081667e+05       3.0       1.75         1510      6360
# 4596    68  5.343333e+05       3.0       2.50         1460      7573
# 4597    68  4.169042e+05       3.0       2.50         3010      7014
# 4598    69  2.034000e+05       4.0       2.00         2090      6630
# 4599    69  2.206000e+05       3.0       2.50         1490      8102
#
#       waterfront  view  condition  sqft_above  sqft_basement  yr_renovated  \
# ...

# %%
sns.kdeplot(data=df["date"],color="Green",fill=True)
plt.title("Distribution")
plt.show()

# %%
sns.kdeplot(data=df["street"],color="Green",fill=True)
plt.title("Distribution")
plt.show()

# %%
sns.kdeplot(data=df["city"],color="Green",fill=True)
plt.title("Distribution")
plt.show()

# %%
sns.kdeplot(data=df["statezip"],color="Green",fill=True)
plt.title("Distribution")
plt.show()

# %%
sns.kdeplot(data=df["country"],color="Green",fill=True)
plt.title("Distribution")
plt.show()
# Out:
# C:\Users\shree\AppData\Local\Temp\ipykernel_5644\4079001854.py:1: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(data=df["country"],color="Green",fill=True)

# %%
df.drop(columns=["date"],inplace=True)
df.drop(columns=["street"],inplace=True)
df.drop(columns=["statezip"],inplace=True)
df.drop(columns=["country"],inplace=True)
df
# Out:
#              price  bedrooms  bathrooms  sqft_living  sqft_lot  waterfront  \
# 0     3.130000e+05       3.0       1.50         1340      7912           0
# 1     2.384000e+06       5.0       2.50         3650      9050           0
# 2     3.420000e+05       3.0       2.00         1930     11947           0
# 3     4.200000e+05       3.0       2.25         2000      8030           0
# 4     5.500000e+05       4.0       2.50         1940     10500           0
# ...            ...       ...        ...          ...       ...         ...
# 4595  3.081667e+05       3.0       1.75         1510      6360           0
# 4596  5.343333e+05       3.0       2.50         1460      7573           0
# 4597  4.169042e+05       3.0       2.50         3010      7014           0
# 4598  2.034000e+05       4.0       2.00         2090      6630           0
# 4599  2.206000e+05       3.0       2.50         1490      8102           0
#
#       view  condition  sqft_above  sqft_basement  yr_renovated  city
# ...

# %%
x=df.drop(columns=["price"],axis=1)
y=df["price"]
x
# Out:
#       bedrooms  bathrooms  sqft_living  sqft_lot  waterfront  view  condition  \
# 0          3.0       1.50         1340      7912           0     0          3
# 1          5.0       2.50         3650      9050           0     4          5
# 2          3.0       2.00         1930     11947           0     0          4
# 3          3.0       2.25         2000      8030           0     0          4
# 4          4.0       2.50         1940     10500           0     0          4
# ...        ...        ...          ...       ...         ...   ...        ...
# 4595       3.0       1.75         1510      6360           0     0          4
# 4596       3.0       2.50         1460      7573           0     0          3
# 4597       3.0       2.50         3010      7014           0     0          3
# 4598       4.0       2.00         2090      6630           0     0          3
# 4599       3.0       2.50         1490      8102           0     0          4
#
# ...

# %%
df
# Out:
#              price  bedrooms  bathrooms  sqft_living  sqft_lot  waterfront  \
# 0     3.130000e+05       3.0       1.50         1340      7912           0
# 1     2.384000e+06       5.0       2.50         3650      9050           0
# 2     3.420000e+05       3.0       2.00         1930     11947           0
# 3     4.200000e+05       3.0       2.25         2000      8030           0
# 4     5.500000e+05       4.0       2.50         1940     10500           0
# ...            ...       ...        ...          ...       ...         ...
# 4595  3.081667e+05       3.0       1.75         1510      6360           0
# 4596  5.343333e+05       3.0       2.50         1460      7573           0
# 4597  4.169042e+05       3.0       2.50         3010      7014           0
# 4598  2.034000e+05       4.0       2.00         2090      6630           0
# 4599  2.206000e+05       3.0       2.50         1490      8102           0
#
#       view  condition  sqft_above  sqft_basement  yr_renovated  city
# ...

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)
x
# Out:
# array([[-0.44112227, -0.84320364, -0.82997105, ..., -0.67246372,
#          1.22167046,  0.8618055 ],
#        [ 1.75970468,  0.43280154,  1.56852826, ..., -0.06912828,
#         -0.82569345,  0.77834292],
#        [-0.44112227, -0.20520105, -0.21736733, ..., -0.67246372,
#         -0.82569345, -0.64052081],
#        ...,
#        [-0.44112227,  0.43280154,  0.90400897, ..., -0.67246372,
#         -0.82569345,  0.5279552 ],
#        [ 0.6592912 , -0.20520105, -0.05123751, ...,  1.5254011 ,
#         -0.82569345,  0.77834292],
#        [-0.44112227,  0.43280154, -0.67422434, ..., -0.67246372,
#         -0.82569345, -1.39168397]], shape=(4600, 11))

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=50)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (3680, 11)
# (920, 11)
# (3680,)
# (920,)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
y_pred=lr.predict(x_test)

# %%
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error
print(r2_score(y_test,y_pred))
print(mean_squared_error(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
# Out:
# 0.5147884999256408
# 61778769738.92061
# 168203.6811305414

# %%
lr.fit(x_test,y_test)
y_pred=lr.predict(x_test)

# %%
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error
print(r2_score(y_test,y_pred))
print(mean_squared_error(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
# Out:
# 0.545411644043482
# 57879727426.75784
# 163879.8491966975

# %%
from sklearn.tree import DecisionTreeRegressor
dt=DecisionTreeRegressor()
dt.fit(x_train,y_train)
y_pred=dt.predict(x_test)

# %%
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error
print(r2_score(y_test,y_pred))
print(mean_squared_error(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
# Out:
# -2.4850274536849826
# 443725485818.0943
# 213659.92614247176

# %%
dt.fit(x_test,y_test)
y_pred=dt.predict(x_test)

# %%
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error
print(r2_score(y_test,y_pred))
print(mean_squared_error(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
# Out:
# 1.0
# 0.0
# 0.0

# %%
from sklearn.ensemble import RandomForestRegressor
rf=RandomForestRegressor()
rf.fit(x_train,y_train)
y_pred=rf.predict(x_test)

# %%
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error
print(r2_score(y_test,y_pred))
print(mean_squared_error(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
# Out:
# 0.3971776535304793
# 76753380598.5823
# 145360.49063113658

# %%
rf.fit(x_test,y_test)
y_pred=rf.predict(x_test)

# %%
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error
print(r2_score(y_test,y_pred))
print(mean_squared_error(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
# Out:
# 0.9383397559965952
# 7850790873.151651
# 54969.57876750593

# %%
from sklearn.neighbors import KNeighborsRegressor
knn=KNeighborsRegressor()
knn.fit(x_train,y_train)
y_pred=knn.predict(x_test)

# %%
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error
print(r2_score(y_test,y_pred))
print(mean_squared_error(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
# Out:
# 0.3603400250052017
# 81443672090.11179
# 176290.44204821112

# %%
knn.fit(x_test,y_test)
y_pred=knn.predict(x_test)

# %%
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error
print(r2_score(y_test,y_pred))
print(mean_squared_error(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
# Out:
# 0.6455868382676637
# 45125082789.153534
# 143136.71556705522

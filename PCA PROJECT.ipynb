# %%
import pandas as pd
input_path = r"C:\Users\shree\Downloads\DATA SCIENCE\UNSUPERVISED LEARNING.ipynb\en.openfoodfacts.org.products.tsv"
output_path = r"C:\Users\shree\Downloads\DATA SCIENCE\UNSUPERVISED LEARNING.ipynb\en.openfoodfacts.org.products.csv"
df = pd.read_csv(input_path, sep="\t", low_memory=False)
df.to_csv(output_path, index=False)
print("Conversion completed!")
# Out:
# Conversion completed!

# %%
df=pd.read_csv(r"C:\Users\shree\Downloads\DATA SCIENCE\UNSUPERVISED LEARNING.ipynb\en.openfoodfacts.org.products.csv")
df
# Out:
# C:\Users\shree\AppData\Local\Temp\ipykernel_17320\2785739616.py:1: DtypeWarning: Columns (0,3,5,19,20,24,25,26,27,28,36,37,38,39,48) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv(r"C:\Users\shree\Downloads\DATA SCIENCE\UNSUPERVISED LEARNING.ipynb\en.openfoodfacts.org.products.csv")
#                  code                                                url  \
# 0                3087  http://world-en.openfoodfacts.org/product/0000...
# 1                4530  http://world-en.openfoodfacts.org/product/0000...
# 2                4559  http://world-en.openfoodfacts.org/product/0000...
# 3               16087  http://world-en.openfoodfacts.org/product/0000...
# 4               16094  http://world-en.openfoodfacts.org/product/0000...
# ...               ...                                                ...
# 356022       99567453  http://world-en.openfoodfacts.org/product/9956...
# ...

# %%
df.isnull().sum().sum()
# Out:
# np.int64(44183489)

# %%
import pandas as pd
import numpy as np
num_cols = df.select_dtypes(include=[np.number]).columns
df[num_cols] = df[num_cols].fillna(df[num_cols].median())
cat_cols = df.select_dtypes(include=['object']).columns
df[cat_cols] = df[cat_cols].fillna(df[cat_cols].mode().iloc[0])
print("Null values filled!")
print(df.isnull().sum().sum())
# Out:
# Null values filled!
# 5696432

# %%
print(df.isnull().sum().sum())
# Out:
# 5696432

# %%
import numpy as np
import pandas as pd
num_cols = df.select_dtypes(include=[np.number]).columns
df[num_cols] = df[num_cols].apply(lambda x: x.fillna(x.median()))
cat_cols = df.select_dtypes(include=['object']).columns
df[cat_cols] = df[cat_cols].apply(
    lambda x: x.fillna(x.mode()[0] if not x.mode().empty else "Unknown")
)
df = df.fillna("Unknown")
print(df.isnull().sum().sum())
# Out:
# c:\Users\shree\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\shree\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\shree\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\shree\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# c:\Users\shree\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\lib\_nanfunctions_impl.py:1215: RuntimeWarning: Mean of empty slice
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 356027 entries, 0 to 356026
# Columns: 163 entries, code to water-hardness_100g
# dtypes: float64(91), object(72)
# memory usage: 442.8+ MB

# %%
print(df.isnull().sum().sum())
# Out:
# 0

# %%
obj_cols = df.select_dtypes(include=['object']).columns
print("Number of object columns:", len(obj_cols))
print(obj_cols.tolist())
# Out:
# Number of object columns: 72
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
obj_cols = df.select_dtypes(include=['object']).columns
for col in obj_cols:
    df[col] = df[col].astype(str)      
    df[col] = le.fit_transform(df[col])
print("All object columns converted to integers!")
# Out:
# All object columns converted to integers!

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 356027 entries, 0 to 356026
# Columns: 163 entries, code to water-hardness_100g
# dtypes: float64(91), int64(72)
# memory usage: 442.8 MB

# %%
from sklearn.preprocessing import StandardScaler
x=df
sc=StandardScaler()
x_scaled=sc.fit_transform(x)
x_scaled
# Out:
# array([[-1.20947491, -1.731793  , -0.18356294, ...,  0.00178836,
#          0.        ,  0.        ],
#        [ 0.01021833, -1.73178327,  0.75908646, ...,  0.64753203,
#          0.        ,  0.        ],
#        [ 0.01157154, -1.73177354,  0.75908646, ..., -1.16055026,
#          0.        ,  0.        ],
#        ...,
#        [ 1.73127232,  1.7320265 , -0.18356294, ...,  0.00178836,
#          0.        ,  0.        ],
#        [ 1.73128206,  1.73203623, -0.18356294, ...,  0.00178836,
#          0.        ,  0.        ],
#        [ 1.73183697,  1.73204596,  0.75908646, ...,  0.00178836,
#          0.        ,  0.        ]], shape=(356027, 163))

# %%
x=df.drop("nutrition-score-fr_100g",axis=1)
y=df["nutrition-score-fr_100g"]
x
# Out:
#           code     url  creator  created_t  created_datetime  last_modified_t  \
# 0        53689       0     2736      94573             94572            59110
# 1       178974       1     3646     151703            151702           113256
# 2       179113       2     3646     151703            151702           113256
# 3        16723       3     3646     138679            138678           100117
# 4        16724       4     3646     138604            138603           100041
# ...        ...     ...      ...        ...               ...              ...
# 356022  355755  355996     3646     141766            141765           151208
# 356023  355757  355997     3577      29501             29500           151208
# 356024  355758  355998     2736     200822            200821           189136
# 356025  355759  355999     2736     187679            187678           155522
# 356026  355816  356000     3646     154168            154167           151208
#
# ...

# %%
y
# Out:
# 0         10.0
# 1         14.0
# 2          0.0
# 3         12.0
# 4         10.0
#           ...
# 356022     0.0
# 356023    10.0
# 356024    10.0
# 356025    10.0
# 356026    10.0
# Name: nutrition-score-fr_100g, Length: 356027, dtype: float64

# %%
df["nutrition-score-fr_100g"].unique()
# Out:
# array([ 10.,  14.,   0.,  12.,   7.,  -6.,  15.,  11.,   9.,  16.,  19.,
#         -1.,   6.,  26.,  13.,  17.,  23.,  30.,   8.,  25.,  -2.,   1.,
#         18.,   2.,  21.,  20.,  22.,   3.,   4.,  24.,  27.,  28.,  -3.,
#         -4.,  -7.,  -5.,   5.,  29.,  31.,  -8.,  -9.,  35.,  33.,  32.,
#         34., -10., -13.,  40.,  37.,  38., -11.,  36., -12., -14., -15.])

# %%
from sklearn.decomposition import PCA
pca=PCA(n_components=80)
x_pca=pca.fit_transform(x_scaled)
x_pca
# Out:
# array([[ 1.10362346,  3.86388487,  0.98992571, ...,  0.58657958,
#          0.0180195 ,  0.05216576],
#        [ 2.31496383, -0.21543658,  2.05432829, ..., -0.37218485,
#         -0.09549267, -0.0832264 ],
#        [ 2.27600603, -1.1202079 , -2.12293604, ...,  0.04943372,
#         -0.07845531, -0.05587912],
#        ...,
#        [ 1.97296182,  4.31094241,  0.80848129, ...,  0.87158839,
#          0.03084627,  0.00676039],
#        [ 2.54043518,  4.33973077,  0.77951404, ..., -0.19498552,
#          0.02481634,  0.03439156],
#        [ 2.06392842, -1.28630521,  0.57465375, ..., -0.67799404,
#          0.10252481,  0.18527832]], shape=(356027, 80))

# %%
print("eigenvalues")
print(pca.explained_variance_)
print("eigenvectors")
print(pca.components_)
# Out:
# eigenvalues
# [10.74642139  4.81446324  3.94622047  3.65044267  3.17573557  3.15028494
#   2.9997985   2.96684233  2.63588453  2.45075434  2.28293514  2.1604535
#   2.00059247  1.95819187  1.8538295   1.77749409  1.75125353  1.74328593
#   1.6580606   1.60002512  1.56280275  1.5148779   1.45358524  1.40245103
#   1.35262482  1.28166075  1.26942208  1.25696037  1.21950797  1.15928996
#   1.12807514  1.12038344  1.11122667  1.07350394  1.06077284  1.03749949
#   1.03190011  1.02987632  1.02552356  1.02083766  1.01819727  1.01596901
#   1.01089627  1.00721035  1.00363379  1.00324252  1.00206416  1.00149741
#   1.00093403  1.00024073  1.00011319  0.99999794  0.99982504  0.99973689
#   0.99949383  0.99909498  0.99854216  0.99768919  0.99678108  0.99547027
#   0.99204025  0.98861808  0.98772936  0.98524945  0.98444948  0.98104707
#   0.97956632  0.9762958   0.96515459  0.9641776   0.96057717  0.94617637
#   0.93699809  0.92909666  0.9267973   0.92447996  0.91066486  0.89530775
# ...

# %%
from sklearn.decomposition import PCA
pca=PCA(n_components=10)
x_pca=pca.fit_transform(x_scaled)
x_pca
# Out:
# array([[ 1.10362346,  3.86388487,  0.98992571, ...,  0.42038524,
#         -0.19885383, -0.54334515],
#        [ 2.31496383, -0.21543658,  2.05432829, ..., -0.00580892,
#         -0.59843392,  1.04321148],
#        [ 2.27600603, -1.1202079 , -2.12293604, ...,  0.11671053,
#          0.45378174,  1.29639031],
#        ...,
#        [ 1.97296182,  4.31094241,  0.80848129, ..., -0.72618015,
#          0.21127847, -0.42256214],
#        [ 2.54043518,  4.33973077,  0.77951404, ..., -0.3101303 ,
#          0.0631284 , -0.19155997],
#        [ 2.06392842, -1.28630521,  0.57465375, ...,  0.09693333,
#         -0.14935499, -2.11113286]], shape=(356027, 10))

# %%
import matplotlib.pyplot as plt
plt.style.use("ggplot")
plt.plot(pca.explained_variance_,marker="o")
plt.show()

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=50)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (284821, 162)
# (71206, 162)
# (284821,)
# (71206,)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression(fit_intercept=True,positive=False,n_jobs=50,tol=2.9)
lr.fit(x_train,y_train)
y_pred=lr.predict(x_test)

# %%
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error
print(r2_score(y_test,y_pred))
print(mean_squared_error(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
# Out:
# 0.9802021200625475
# 1.1478256411881982
# 0.6510818486220729

# %%
lr=LinearRegression(fit_intercept=True,positive=False,n_jobs=60,tol=1.3)
lr.fit(x_test,y_test)
y_pred=lr.predict(x_test)

# %%
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error
print(r2_score(y_test,y_pred))
print(mean_squared_error(y_test,y_pred))
print(mean_absolute_error(y_test,y_pred))
# Out:
# 0.9804124355763741
# 1.1356321366173798
# 0.6538286434926532
